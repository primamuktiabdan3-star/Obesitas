# %%
data_inferensi = {
    'Gender': ['Male', 'Female'],
    'Age': [25.0, 30.0],
    'Height': [1.75, 1.60],
    'Weight': [70.0, 65.0],
    'family_history': ['yes', 'no'],
    'FAVC': ['yes', 'no'],
    'FCVC': [2.0, 3.0],
    'NCP': [3.0, 4.0],
    'CAEC': ['Sometimes', 'Frequently'],
    'SMOKE': ['no', 'yes'],
    'CH2O': [2.0, 3.0],
    'SCC': ['no', 'yes'],
    'FAF': [1.0, 2.0],
    'TUE': [1.0, 0.0],
    'CALC': ['Sometimes', 'No'],
    'MTRANS': ['Public_Transportation', 'Automobile']
}
df_inferensi = pd.DataFrame(data_inferensi)
